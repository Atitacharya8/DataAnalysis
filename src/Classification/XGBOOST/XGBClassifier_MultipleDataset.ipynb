# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
current_directory = 'C:\\Users\\Atit Acharya\\OneDrive - The University of Texas at Tyler\\Desktop\\Research\\Classification\\XGBOOST'
# print(current_directory)

acc_XGB = []
acc_DMat = []
for filename in os.listdir(current_directory):
#     print(filename)
    if os.path.isfile(os.path.join(current_directory, filename)) and '.csv' in filename:
#         # Do something with the file
        print("\n-------------------------------------------------------------------\n")
        data = pd.read_csv(filename)
        train, test = train_test_split(data, test_size=0.2, random_state=42)
        train, val = train_test_split(train, test_size=0.2, random_state=42)
        
        
        X_train = train.drop(['LastStatementMinimumPaymentDueAmount', 'CardExternalStatus','Target', 'LastStatementBalanceAmount'] , axis=1)
#         X_train = train.drop('Target', axis=1)
        y_train = train['Target']
        
        
        X_val = val.drop(['LastStatementMinimumPaymentDueAmount' , 'CardExternalStatus', 'Target', 'LastStatementBalanceAmount'] , axis=1)
#         X_val = val.drop('Target', axis=1)
        y_val = val['Target']
        
        X_test = test.drop(['LastStatementMinimumPaymentDueAmount', 'CardExternalStatus', 'Target', 'LastStatementBalanceAmount'] , axis=1)
#         X_test = test.drop('Target', axis=1)
        y_test = test['Target']
        
        params = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'max_depth': 10,
            'learning_rate': 0.1,
            'n_estimators': 100,
             'gamma' : 0.1,
            'reg_alpha' : 0.1,
            'reg_lamdba':0.1
        }
        
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dval = xgb.DMatrix(X_val, label=y_val)
        
        model = xgb.train(params, dtrain, evals=[(dval, 'validation')], early_stopping_rounds=10)
        
        dtest = xgb.DMatrix(X_test)
        
        y_pred = model.predict(dtest)
        y_pred = np.round(y_pred)
        
        Dmatrix_accuracy = accuracy_score(y_test, y_pred)
        
        print('Accuracy using DMatrix: {:.2f}%'.format(Dmatrix_accuracy * 100))
        
        # initialize the XGBClassifier model with pruning parameters
        clf = XGBClassifier(
            max_depth=3,          # Maximum tree depth
            learning_rate=0.1,    # Learning rate
#             n_estimators=100,     # Number of trees in the forest
            gamma=0.1,            # Minimum loss reduction to make a further partition
            reg_alpha=0.1,        # L1 regularization on leaf weights
#             reg_lambda=0.1,       # L2 regularization on leaf weights
            subsample=0.8,        # Subsample ratio of the training set
            colsample_bytree=0.8  # Subsample ratio of columns when constructing each tree
        )
        
        # train the XGBClassifier model on the training set
        clf.fit(X_train, y_train)
        
        # evaluate the accuracy of the model on the testing set
        XGBClassifier_accuracy = clf.score(X_test, y_test)
        print("Accuracy using XGBClassifier: %.2f%%" % (XGBClassifier_accuracy * 100.0))

        acc_XGB.append(XGBClassifier_accuracy)
        acc_DMat.append(Dmatrix_accuracy)

Average_XGBClassifier = np.mean(acc_XGB)
print(Average_XGBClassifier)

Average_DMatrix = np.mean(acc_DMat)
print(Average_DMatrix)
# Out:
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65328
# [1]	validation-logloss:0.61827
# [2]	validation-logloss:0.59520
# [3]	validation-logloss:0.58384
# [4]	validation-logloss:0.55968
# [5]	validation-logloss:0.54207
# [6]	validation-logloss:0.52383
# [7]	validation-logloss:0.50788
# [8]	validation-logloss:0.49868
# [9]	validation-logloss:0.49009
# Accuracy using DMatrix: 82.37%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64762
# [1]	validation-logloss:0.60750
# [2]	validation-logloss:0.57949
# [3]	validation-logloss:0.56180
# [4]	validation-logloss:0.53629
# [5]	validation-logloss:0.51554
# [6]	validation-logloss:0.49448
# [7]	validation-logloss:0.47607
# [8]	validation-logloss:0.46579
# [9]	validation-logloss:0.45478
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 80.58%
#
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65294
# [1]	validation-logloss:0.61666
# [2]	validation-logloss:0.58929
# [3]	validation-logloss:0.57530
# [4]	validation-logloss:0.55228
# [5]	validation-logloss:0.53241
# [6]	validation-logloss:0.51408
# [7]	validation-logloss:0.49572
# [8]	validation-logloss:0.48701
# [9]	validation-logloss:0.47812
# Accuracy using DMatrix: 78.12%
# Accuracy using XGBClassifier: 79.24%
#
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64956
# [1]	validation-logloss:0.60944
# [2]	validation-logloss:0.57778
# [3]	validation-logloss:0.56271
# [4]	validation-logloss:0.53694
# [5]	validation-logloss:0.51414
# [6]	validation-logloss:0.49468
# [7]	validation-logloss:0.47572
# [8]	validation-logloss:0.46426
# [9]	validation-logloss:0.45209
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65118
# [1]	validation-logloss:0.61172
# [2]	validation-logloss:0.57898
# [3]	validation-logloss:0.56612
# [4]	validation-logloss:0.54381
# [5]	validation-logloss:0.52366
# [6]	validation-logloss:0.50185
# [7]	validation-logloss:0.48232
# [8]	validation-logloss:0.46918
# [9]	validation-logloss:0.45865
# Accuracy using DMatrix: 83.26%
# Accuracy using XGBClassifier: 83.48%
#
# -------------------------------------------------------------------
#
# [01:24:07] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65229
# [1]	validation-logloss:0.61308
# [2]	validation-logloss:0.58428
# [3]	validation-logloss:0.57072
# [4]	validation-logloss:0.54745
# [5]	validation-logloss:0.52715
# [6]	validation-logloss:0.50720
# [7]	validation-logloss:0.48938
# [8]	validation-logloss:0.47908
# [9]	validation-logloss:0.46909
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 82.59%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65152
# [1]	validation-logloss:0.61124
# [2]	validation-logloss:0.57880
# [3]	validation-logloss:0.56530
# [4]	validation-logloss:0.53780
# [5]	validation-logloss:0.51719
# [6]	validation-logloss:0.49663
# [7]	validation-logloss:0.47712
# [8]	validation-logloss:0.46403
# [9]	validation-logloss:0.45187
# Accuracy using DMatrix: 78.57%
# Accuracy using XGBClassifier: 79.24%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64871
# [1]	validation-logloss:0.61207
# [2]	validation-logloss:0.58531
# [3]	validation-logloss:0.56860
# [4]	validation-logloss:0.54565
# [5]	validation-logloss:0.52289
# [6]	validation-logloss:0.50154
# [7]	validation-logloss:0.48565
# [8]	validation-logloss:0.47682
# [9]	validation-logloss:0.46722
# Accuracy using DMatrix: 83.48%
# Accuracy using XGBClassifier: 83.26%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64945
# [1]	validation-logloss:0.61046
# [2]	validation-logloss:0.58282
# [3]	validation-logloss:0.56626
# [4]	validation-logloss:0.54215
# [5]	validation-logloss:0.52151
# [6]	validation-logloss:0.50055
# [7]	validation-logloss:0.48391
# [8]	validation-logloss:0.47393
# [9]	validation-logloss:0.46344
# Accuracy using DMatrix: 83.04%
# Accuracy using XGBClassifier: 83.71%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64727
# [1]	validation-logloss:0.60683
# [2]	validation-logloss:0.57694
# [3]	validation-logloss:0.56145
# [4]	validation-logloss:0.53629
# [5]	validation-logloss:0.51575
# [6]	validation-logloss:0.49552
# [7]	validation-logloss:0.47596
# [8]	validation-logloss:0.46421
# [9]	validation-logloss:0.45214
# Accuracy using DMatrix: 79.91%
# Accuracy using XGBClassifier: 82.37%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65438
# [1]	validation-logloss:0.61750
# [2]	validation-logloss:0.59120
# [3]	validation-logloss:0.57892
# [4]	validation-logloss:0.55460
# [5]	validation-logloss:0.53458
# [6]	validation-logloss:0.51568
# [7]	validation-logloss:0.50032
# [8]	validation-logloss:0.48976
# [9]	validation-logloss:0.47832
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 79.24%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65033
# [1]	validation-logloss:0.61685
# [2]	validation-logloss:0.58646
# [3]	validation-logloss:0.57117
# [4]	validation-logloss:0.54702
# [5]	validation-logloss:0.52425
# [6]	validation-logloss:0.50413
# [7]	validation-logloss:0.48681
# [8]	validation-logloss:0.47707
# [9]	validation-logloss:0.46565
# Accuracy using DMatrix: 79.02%
# Accuracy using XGBClassifier: 79.24%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64900
# [1]	validation-logloss:0.60968
# [2]	validation-logloss:0.58219
# [3]	validation-logloss:0.56346
# [4]	validation-logloss:0.53769
# [5]	validation-logloss:0.51648
# [6]	validation-logloss:0.49340
# [7]	validation-logloss:0.47335
# [8]	validation-logloss:0.46208
# [9]	validation-logloss:0.45190
# Accuracy using DMatrix: 79.69%
# Accuracy using XGBClassifier: 79.91%
#
# -------------------------------------------------------------------
#
# [01:24:08] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65242
# [1]	validation-logloss:0.61552
# [2]	validation-logloss:0.58672
# [3]	validation-logloss:0.57486
# [4]	validation-logloss:0.55086
# [5]	validation-logloss:0.53214
# [6]	validation-logloss:0.51376
# [7]	validation-logloss:0.49695
# [8]	validation-logloss:0.48532
# [9]	validation-logloss:0.47400
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 80.13%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65228
# [1]	validation-logloss:0.61741
# [2]	validation-logloss:0.58882
# [3]	validation-logloss:0.57302
# [4]	validation-logloss:0.55137
# [5]	validation-logloss:0.52994
# [6]	validation-logloss:0.50893
# [7]	validation-logloss:0.49238
# [8]	validation-logloss:0.48188
# [9]	validation-logloss:0.47086
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 82.37%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65207
# [1]	validation-logloss:0.61323
# [2]	validation-logloss:0.58206
# [3]	validation-logloss:0.56634
# [4]	validation-logloss:0.53767
# [5]	validation-logloss:0.51706
# [6]	validation-logloss:0.49547
# [7]	validation-logloss:0.47524
# [8]	validation-logloss:0.46276
# [9]	validation-logloss:0.45032
# Accuracy using DMatrix: 77.90%
# Accuracy using XGBClassifier: 79.46%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65068
# [1]	validation-logloss:0.61425
# [2]	validation-logloss:0.58644
# [3]	validation-logloss:0.57086
# [4]	validation-logloss:0.54645
# [5]	validation-logloss:0.52565
# [6]	validation-logloss:0.50464
# [7]	validation-logloss:0.48629
# [8]	validation-logloss:0.47460
# [9]	validation-logloss:0.46289
# Accuracy using DMatrix: 82.37%
# Accuracy using XGBClassifier: 82.81%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65018
# [1]	validation-logloss:0.61174
# [2]	validation-logloss:0.58182
# [3]	validation-logloss:0.56741
# [4]	validation-logloss:0.54233
# [5]	validation-logloss:0.52004
# [6]	validation-logloss:0.49885
# [7]	validation-logloss:0.48070
# [8]	validation-logloss:0.47096
# [9]	validation-logloss:0.46187
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 79.02%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65224
# [1]	validation-logloss:0.61417
# [2]	validation-logloss:0.58482
# [3]	validation-logloss:0.56941
# [4]	validation-logloss:0.54485
# [5]	validation-logloss:0.52660
# [6]	validation-logloss:0.50679
# [7]	validation-logloss:0.48825
# [8]	validation-logloss:0.47774
# [9]	validation-logloss:0.46900
# Accuracy using DMatrix: 83.04%
# Accuracy using XGBClassifier: 83.48%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64896
# [1]	validation-logloss:0.61042
# [2]	validation-logloss:0.58190
# [3]	validation-logloss:0.56831
# [4]	validation-logloss:0.54234
# [5]	validation-logloss:0.52040
# [6]	validation-logloss:0.50068
# [7]	validation-logloss:0.48207
# [8]	validation-logloss:0.46969
# [9]	validation-logloss:0.45674
# Accuracy using DMatrix: 79.69%
# Accuracy using XGBClassifier: 80.80%
#
# -------------------------------------------------------------------
#
# [01:24:09] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65269
# [1]	validation-logloss:0.61346
# [2]	validation-logloss:0.58725
# [3]	validation-logloss:0.57184
# [4]	validation-logloss:0.54855
# [5]	validation-logloss:0.52879
# [6]	validation-logloss:0.50656
# [7]	validation-logloss:0.49032
# [8]	validation-logloss:0.47839
# [9]	validation-logloss:0.46822
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65380
# [1]	validation-logloss:0.61845
# [2]	validation-logloss:0.58972
# [3]	validation-logloss:0.57522
# [4]	validation-logloss:0.55121
# [5]	validation-logloss:0.53238
# [6]	validation-logloss:0.51364
# [7]	validation-logloss:0.49638
# [8]	validation-logloss:0.48385
# [9]	validation-logloss:0.47257
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 79.02%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64723
# [1]	validation-logloss:0.60868
# [2]	validation-logloss:0.58201
# [3]	validation-logloss:0.56597
# [4]	validation-logloss:0.53979
# [5]	validation-logloss:0.51657
# [6]	validation-logloss:0.49561
# [7]	validation-logloss:0.47711
# [8]	validation-logloss:0.46847
# [9]	validation-logloss:0.45813
# Accuracy using DMatrix: 82.59%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64759
# [1]	validation-logloss:0.60794
# [2]	validation-logloss:0.57670
# [3]	validation-logloss:0.55706
# [4]	validation-logloss:0.53051
# [5]	validation-logloss:0.50945
# [6]	validation-logloss:0.48885
# [7]	validation-logloss:0.47030
# [8]	validation-logloss:0.45803
# [9]	validation-logloss:0.44638
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 83.93%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64946
# [1]	validation-logloss:0.61040
# [2]	validation-logloss:0.58179
# [3]	validation-logloss:0.56651
# [4]	validation-logloss:0.54109
# [5]	validation-logloss:0.52058
# [6]	validation-logloss:0.49896
# [7]	validation-logloss:0.48141
# [8]	validation-logloss:0.46985
# [9]	validation-logloss:0.45970
# Accuracy using DMatrix: 81.47%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65295
# [1]	validation-logloss:0.61639
# [2]	validation-logloss:0.58697
# [3]	validation-logloss:0.57520
# [4]	validation-logloss:0.55187
# [5]	validation-logloss:0.53357
# [6]	validation-logloss:0.51387
# [7]	validation-logloss:0.49635
# [8]	validation-logloss:0.48898
# [9]	validation-logloss:0.47947
# Accuracy using DMatrix: 83.48%
# Accuracy using XGBClassifier: 83.26%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65338
# [1]	validation-logloss:0.61732
# [2]	validation-logloss:0.59169
# [3]	validation-logloss:0.57831
# [4]	validation-logloss:0.55497
# [5]	validation-logloss:0.53717
# [6]	validation-logloss:0.51875
# [7]	validation-logloss:0.50292
# [8]	validation-logloss:0.49421
# [9]	validation-logloss:0.48397
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65257
# [1]	validation-logloss:0.61091
# [2]	validation-logloss:0.57828
# [3]	validation-logloss:0.56404
# [4]	validation-logloss:0.53657
# [5]	validation-logloss:0.51463
# [6]	validation-logloss:0.49277
# [7]	validation-logloss:0.47295
# [8]	validation-logloss:0.46019
# [9]	validation-logloss:0.44748
# Accuracy using DMatrix: 79.02%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:10] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65294
# [1]	validation-logloss:0.61346
# [2]	validation-logloss:0.58093
# [3]	validation-logloss:0.56783
# [4]	validation-logloss:0.54091
# [5]	validation-logloss:0.52149
# [6]	validation-logloss:0.49993
# [7]	validation-logloss:0.48042
# [8]	validation-logloss:0.46613
# [9]	validation-logloss:0.45231
# Accuracy using DMatrix: 78.79%
# Accuracy using XGBClassifier: 79.24%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65215
# [1]	validation-logloss:0.61125
# [2]	validation-logloss:0.58127
# [3]	validation-logloss:0.56699
# [4]	validation-logloss:0.54129
# [5]	validation-logloss:0.52557
# [6]	validation-logloss:0.50882
# [7]	validation-logloss:0.49102
# [8]	validation-logloss:0.47927
# [9]	validation-logloss:0.46777
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 80.80%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65105
# [1]	validation-logloss:0.61348
# [2]	validation-logloss:0.58570
# [3]	validation-logloss:0.57133
# [4]	validation-logloss:0.54677
# [5]	validation-logloss:0.52487
# [6]	validation-logloss:0.50543
# [7]	validation-logloss:0.48883
# [8]	validation-logloss:0.47725
# [9]	validation-logloss:0.46747
# Accuracy using DMatrix: 81.47%
# Accuracy using XGBClassifier: 83.48%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65213
# [1]	validation-logloss:0.61624
# [2]	validation-logloss:0.58991
# [3]	validation-logloss:0.57695
# [4]	validation-logloss:0.55541
# [5]	validation-logloss:0.53491
# [6]	validation-logloss:0.51595
# [7]	validation-logloss:0.49966
# [8]	validation-logloss:0.48818
# [9]	validation-logloss:0.47867
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65088
# [1]	validation-logloss:0.61554
# [2]	validation-logloss:0.58650
# [3]	validation-logloss:0.57345
# [4]	validation-logloss:0.55115
# [5]	validation-logloss:0.53024
# [6]	validation-logloss:0.51040
# [7]	validation-logloss:0.49299
# [8]	validation-logloss:0.48366
# [9]	validation-logloss:0.47230
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65021
# [1]	validation-logloss:0.61563
# [2]	validation-logloss:0.58669
# [3]	validation-logloss:0.57106
# [4]	validation-logloss:0.54608
# [5]	validation-logloss:0.52370
# [6]	validation-logloss:0.50351
# [7]	validation-logloss:0.48824
# [8]	validation-logloss:0.47641
# [9]	validation-logloss:0.46494
# Accuracy using DMatrix: 79.69%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65029
# [1]	validation-logloss:0.61261
# [2]	validation-logloss:0.58441
# [3]	validation-logloss:0.56924
# [4]	validation-logloss:0.54349
# [5]	validation-logloss:0.52213
# [6]	validation-logloss:0.50352
# [7]	validation-logloss:0.48673
# [8]	validation-logloss:0.47463
# [9]	validation-logloss:0.46448
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 83.26%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65447
# [1]	validation-logloss:0.61881
# [2]	validation-logloss:0.59232
# [3]	validation-logloss:0.58037
# [4]	validation-logloss:0.55694
# [5]	validation-logloss:0.53894
# [6]	validation-logloss:0.51896
# [7]	validation-logloss:0.50108
# [8]	validation-logloss:0.49181
# [9]	validation-logloss:0.48174
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 80.58%
#
# -------------------------------------------------------------------
#
# [01:24:11] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65293
# [1]	validation-logloss:0.61361
# [2]	validation-logloss:0.58380
# [3]	validation-logloss:0.57037
# [4]	validation-logloss:0.54619
# [5]	validation-logloss:0.52820
# [6]	validation-logloss:0.50668
# [7]	validation-logloss:0.48891
# [8]	validation-logloss:0.47701
# [9]	validation-logloss:0.46522
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 81.47%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65413
# [1]	validation-logloss:0.61750
# [2]	validation-logloss:0.58951
# [3]	validation-logloss:0.57216
# [4]	validation-logloss:0.54635
# [5]	validation-logloss:0.52709
# [6]	validation-logloss:0.50579
# [7]	validation-logloss:0.48878
# [8]	validation-logloss:0.47695
# [9]	validation-logloss:0.46745
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 80.13%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64977
# [1]	validation-logloss:0.61055
# [2]	validation-logloss:0.58135
# [3]	validation-logloss:0.56834
# [4]	validation-logloss:0.54213
# [5]	validation-logloss:0.52172
# [6]	validation-logloss:0.50079
# [7]	validation-logloss:0.48282
# [8]	validation-logloss:0.47221
# [9]	validation-logloss:0.46358
# Accuracy using DMatrix: 79.91%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64870
# [1]	validation-logloss:0.61105
# [2]	validation-logloss:0.58438
# [3]	validation-logloss:0.56832
# [4]	validation-logloss:0.54429
# [5]	validation-logloss:0.52369
# [6]	validation-logloss:0.50297
# [7]	validation-logloss:0.48600
# [8]	validation-logloss:0.47449
# [9]	validation-logloss:0.46546
# Accuracy using DMatrix: 81.03%
# Accuracy using XGBClassifier: 79.91%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65579
# [1]	validation-logloss:0.61729
# [2]	validation-logloss:0.59145
# [3]	validation-logloss:0.58040
# [4]	validation-logloss:0.55517
# [5]	validation-logloss:0.53675
# [6]	validation-logloss:0.51769
# [7]	validation-logloss:0.49883
# [8]	validation-logloss:0.48889
# [9]	validation-logloss:0.47775
# Accuracy using DMatrix: 78.35%
# Accuracy using XGBClassifier: 79.46%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65282
# [1]	validation-logloss:0.61293
# [2]	validation-logloss:0.58278
# [3]	validation-logloss:0.56965
# [4]	validation-logloss:0.54502
# [5]	validation-logloss:0.52570
# [6]	validation-logloss:0.50640
# [7]	validation-logloss:0.48826
# [8]	validation-logloss:0.47647
# [9]	validation-logloss:0.46584
# Accuracy using DMatrix: 82.81%
# Accuracy using XGBClassifier: 83.04%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65294
# [1]	validation-logloss:0.62060
# [2]	validation-logloss:0.59264
# [3]	validation-logloss:0.58044
# [4]	validation-logloss:0.55993
# [5]	validation-logloss:0.54150
# [6]	validation-logloss:0.52363
# [7]	validation-logloss:0.50723
# [8]	validation-logloss:0.49678
# [9]	validation-logloss:0.48540
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 80.80%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65247
# [1]	validation-logloss:0.61193
# [2]	validation-logloss:0.58156
# [3]	validation-logloss:0.56709
# [4]	validation-logloss:0.53907
# [5]	validation-logloss:0.51910
# [6]	validation-logloss:0.49757
# [7]	validation-logloss:0.47812
# [8]	validation-logloss:0.46847
# [9]	validation-logloss:0.45825
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65314
# [1]	validation-logloss:0.61530
# [2]	validation-logloss:0.58423
# [3]	validation-logloss:0.57196
# [4]	validation-logloss:0.54550
# [5]	validation-logloss:0.52647
# [6]	validation-logloss:0.50569
# [7]	validation-logloss:0.48846
# [8]	validation-logloss:0.47534
# [9]	validation-logloss:0.46431
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65225
# [1]	validation-logloss:0.61407
# [2]	validation-logloss:0.58612
# [3]	validation-logloss:0.56975
# [4]	validation-logloss:0.54765
# [5]	validation-logloss:0.52676
# [6]	validation-logloss:0.50852
# [7]	validation-logloss:0.49144
# [8]	validation-logloss:0.47973
# [9]	validation-logloss:0.46864
# Accuracy using DMatrix: 82.59%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65032
# [1]	validation-logloss:0.61108
# [2]	validation-logloss:0.58261
# [3]	validation-logloss:0.56823
# [4]	validation-logloss:0.54390
# [5]	validation-logloss:0.52398
# [6]	validation-logloss:0.50298
# [7]	validation-logloss:0.48410
# [8]	validation-logloss:0.47260
# [9]	validation-logloss:0.46135
# Accuracy using DMatrix: 82.14%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65072
# [1]	validation-logloss:0.61464
# [2]	validation-logloss:0.58695
# [3]	validation-logloss:0.56792
# [4]	validation-logloss:0.54568
# [5]	validation-logloss:0.52466
# [6]	validation-logloss:0.50632
# [7]	validation-logloss:0.48705
# [8]	validation-logloss:0.47668
# [9]	validation-logloss:0.46831
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 79.46%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65370
# [1]	validation-logloss:0.61944
# [2]	validation-logloss:0.59337
# [3]	validation-logloss:0.57940
# [4]	validation-logloss:0.55770
# [5]	validation-logloss:0.54059
# [6]	validation-logloss:0.52412
# [7]	validation-logloss:0.50991
# [8]	validation-logloss:0.49892
# [9]	validation-logloss:0.48825
# Accuracy using DMatrix: 79.46%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65143
# [1]	validation-logloss:0.61609
# [2]	validation-logloss:0.58964
# [3]	validation-logloss:0.57269
# [4]	validation-logloss:0.54923
# [5]	validation-logloss:0.52969
# [6]	validation-logloss:0.50959
# [7]	validation-logloss:0.49387
# [8]	validation-logloss:0.48428
# [9]	validation-logloss:0.47426
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65728
# [1]	validation-logloss:0.62459
# [2]	validation-logloss:0.59779
# [3]	validation-logloss:0.58741
# [4]	validation-logloss:0.56949
# [5]	validation-logloss:0.55178
# [6]	validation-logloss:0.53497
# [7]	validation-logloss:0.52099
# [8]	validation-logloss:0.51296
# [9]	validation-logloss:0.50368
# Accuracy using DMatrix: 78.12%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65165
# [1]	validation-logloss:0.61513
# [2]	validation-logloss:0.58918
# [3]	validation-logloss:0.57568
# [4]	validation-logloss:0.55187
# [5]	validation-logloss:0.53309
# [6]	validation-logloss:0.51467
# [7]	validation-logloss:0.49655
# [8]	validation-logloss:0.48651
# [9]	validation-logloss:0.47593
# Accuracy using DMatrix: 78.79%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65189
# [1]	validation-logloss:0.61472
# [2]	validation-logloss:0.58794
# [3]	validation-logloss:0.57480
# [4]	validation-logloss:0.54955
# [5]	validation-logloss:0.53012
# [6]	validation-logloss:0.51047
# [7]	validation-logloss:0.49216
# [8]	validation-logloss:0.47919
# [9]	validation-logloss:0.46794
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65032
# [1]	validation-logloss:0.61274
# [2]	validation-logloss:0.58583
# [3]	validation-logloss:0.57048
# [4]	validation-logloss:0.54446
# [5]	validation-logloss:0.52486
# [6]	validation-logloss:0.50382
# [7]	validation-logloss:0.48696
# [8]	validation-logloss:0.47532
# [9]	validation-logloss:0.46397
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 82.59%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65378
# [1]	validation-logloss:0.61727
# [2]	validation-logloss:0.59130
# [3]	validation-logloss:0.57822
# [4]	validation-logloss:0.55323
# [5]	validation-logloss:0.53525
# [6]	validation-logloss:0.51715
# [7]	validation-logloss:0.50228
# [8]	validation-logloss:0.49117
# [9]	validation-logloss:0.48153
# Accuracy using DMatrix: 83.48%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65341
# [1]	validation-logloss:0.61470
# [2]	validation-logloss:0.58807
# [3]	validation-logloss:0.57201
# [4]	validation-logloss:0.54579
# [5]	validation-logloss:0.52866
# [6]	validation-logloss:0.50951
# [7]	validation-logloss:0.49197
# [8]	validation-logloss:0.48135
# [9]	validation-logloss:0.47272
# Accuracy using DMatrix: 81.25%
# Accuracy using XGBClassifier: 80.58%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65423
# [1]	validation-logloss:0.61698
# [2]	validation-logloss:0.59038
# [3]	validation-logloss:0.57713
# [4]	validation-logloss:0.55274
# [5]	validation-logloss:0.53645
# [6]	validation-logloss:0.51563
# [7]	validation-logloss:0.49768
# [8]	validation-logloss:0.48863
# [9]	validation-logloss:0.47981
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65074
# [1]	validation-logloss:0.61029
# [2]	validation-logloss:0.58054
# [3]	validation-logloss:0.56873
# [4]	validation-logloss:0.54408
# [5]	validation-logloss:0.52346
# [6]	validation-logloss:0.50278
# [7]	validation-logloss:0.48236
# [8]	validation-logloss:0.47038
# [9]	validation-logloss:0.45814
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65322
# [1]	validation-logloss:0.61558
# [2]	validation-logloss:0.58644
# [3]	validation-logloss:0.57206
# [4]	validation-logloss:0.54687
# [5]	validation-logloss:0.52664
# [6]	validation-logloss:0.50598
# [7]	validation-logloss:0.48930
# [8]	validation-logloss:0.47864
# [9]	validation-logloss:0.46768
# Accuracy using DMatrix: 82.14%
# Accuracy using XGBClassifier: 82.59%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64941
# [1]	validation-logloss:0.60969
# [2]	validation-logloss:0.57982
# [3]	validation-logloss:0.56821
# [4]	validation-logloss:0.54189
# [5]	validation-logloss:0.52181
# [6]	validation-logloss:0.49925
# [7]	validation-logloss:0.48066
# [8]	validation-logloss:0.46913
# [9]	validation-logloss:0.45877
# Accuracy using DMatrix: 79.69%
# Accuracy using XGBClassifier: 81.47%
#
# -------------------------------------------------------------------
#
# [01:24:14] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65285
# [1]	validation-logloss:0.61504
# [2]	validation-logloss:0.58553
# [3]	validation-logloss:0.57281
# [4]	validation-logloss:0.54794
# [5]	validation-logloss:0.52898
# [6]	validation-logloss:0.50754
# [7]	validation-logloss:0.48786
# [8]	validation-logloss:0.47698
# [9]	validation-logloss:0.46531
# Accuracy using DMatrix: 83.26%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65106
# [1]	validation-logloss:0.61416
# [2]	validation-logloss:0.58428
# [3]	validation-logloss:0.56889
# [4]	validation-logloss:0.54447
# [5]	validation-logloss:0.52591
# [6]	validation-logloss:0.50648
# [7]	validation-logloss:0.48937
# [8]	validation-logloss:0.47830
# [9]	validation-logloss:0.46710
# Accuracy using DMatrix: 81.47%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65203
# [1]	validation-logloss:0.61486
# [2]	validation-logloss:0.58756
# [3]	validation-logloss:0.57281
# [4]	validation-logloss:0.54767
# [5]	validation-logloss:0.52630
# [6]	validation-logloss:0.50770
# [7]	validation-logloss:0.49268
# [8]	validation-logloss:0.48367
# [9]	validation-logloss:0.47448
# Accuracy using DMatrix: 81.47%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64805
# [1]	validation-logloss:0.60614
# [2]	validation-logloss:0.57718
# [3]	validation-logloss:0.55983
# [4]	validation-logloss:0.53348
# [5]	validation-logloss:0.51116
# [6]	validation-logloss:0.48839
# [7]	validation-logloss:0.46851
# [8]	validation-logloss:0.45740
# [9]	validation-logloss:0.44599
# Accuracy using DMatrix: 77.23%
# Accuracy using XGBClassifier: 77.46%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65105
# [1]	validation-logloss:0.61299
# [2]	validation-logloss:0.58256
# [3]	validation-logloss:0.56521
# [4]	validation-logloss:0.54059
# [5]	validation-logloss:0.51986
# [6]	validation-logloss:0.49848
# [7]	validation-logloss:0.48056
# [8]	validation-logloss:0.46789
# [9]	validation-logloss:0.45676
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65137
# [1]	validation-logloss:0.61185
# [2]	validation-logloss:0.57980
# [3]	validation-logloss:0.56272
# [4]	validation-logloss:0.53833
# [5]	validation-logloss:0.51784
# [6]	validation-logloss:0.49692
# [7]	validation-logloss:0.47987
# [8]	validation-logloss:0.46634
# [9]	validation-logloss:0.45337
# Accuracy using DMatrix: 82.37%
# Accuracy using XGBClassifier: 83.48%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64829
# [1]	validation-logloss:0.60587
# [2]	validation-logloss:0.57612
# [3]	validation-logloss:0.55783
# [4]	validation-logloss:0.52814
# [5]	validation-logloss:0.50924
# [6]	validation-logloss:0.48844
# [7]	validation-logloss:0.46977
# [8]	validation-logloss:0.45685
# [9]	validation-logloss:0.44448
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 80.58%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65501
# [1]	validation-logloss:0.61542
# [2]	validation-logloss:0.58933
# [3]	validation-logloss:0.57690
# [4]	validation-logloss:0.55159
# [5]	validation-logloss:0.53460
# [6]	validation-logloss:0.51444
# [7]	validation-logloss:0.49633
# [8]	validation-logloss:0.48645
# [9]	validation-logloss:0.47469
# Accuracy using DMatrix: 82.14%
# Accuracy using XGBClassifier: 82.59%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65319
# [1]	validation-logloss:0.61539
# [2]	validation-logloss:0.58771
# [3]	validation-logloss:0.57620
# [4]	validation-logloss:0.55283
# [5]	validation-logloss:0.53514
# [6]	validation-logloss:0.51467
# [7]	validation-logloss:0.49735
# [8]	validation-logloss:0.48745
# [9]	validation-logloss:0.48055
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 81.47%
#
# -------------------------------------------------------------------
#
# [01:24:15] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65039
# [1]	validation-logloss:0.61110
# [2]	validation-logloss:0.58225
# [3]	validation-logloss:0.56890
# [4]	validation-logloss:0.54130
# [5]	validation-logloss:0.52049
# [6]	validation-logloss:0.50120
# [7]	validation-logloss:0.48401
# [8]	validation-logloss:0.47173
# [9]	validation-logloss:0.46173
# Accuracy using DMatrix: 81.25%
# Accuracy using XGBClassifier: 83.26%
#
# -------------------------------------------------------------------
#
# [01:24:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65011
# [1]	validation-logloss:0.61308
# [2]	validation-logloss:0.58586
# [3]	validation-logloss:0.56937
# [4]	validation-logloss:0.54623
# [5]	validation-logloss:0.52421
# [6]	validation-logloss:0.50564
# [7]	validation-logloss:0.48647
# [8]	validation-logloss:0.47702
# [9]	validation-logloss:0.46770
# Accuracy using DMatrix: 78.57%
# Accuracy using XGBClassifier: 79.46%
#
# -------------------------------------------------------------------
#
# [01:24:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65389
# [1]	validation-logloss:0.61741
# [2]	validation-logloss:0.58872
# [3]	validation-logloss:0.57796
# [4]	validation-logloss:0.55486
# [5]	validation-logloss:0.53610
# [6]	validation-logloss:0.51627
# [7]	validation-logloss:0.49992
# [8]	validation-logloss:0.48867
# [9]	validation-logloss:0.47625
# Accuracy using DMatrix: 82.14%
# Accuracy using XGBClassifier: 83.04%
#
# -------------------------------------------------------------------
#
# ...
#
# -------------------------------------------------------------------
#
# [01:24:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64825
# [1]	validation-logloss:0.60733
# [2]	validation-logloss:0.57584
# [3]	validation-logloss:0.56216
# [4]	validation-logloss:0.53677
# [5]	validation-logloss:0.51512
# [6]	validation-logloss:0.49317
# [7]	validation-logloss:0.47391
# [8]	validation-logloss:0.46334
# [9]	validation-logloss:0.45334
# Accuracy using DMatrix: 80.80%
# Accuracy using XGBClassifier: 82.37%
#
# -------------------------------------------------------------------
#
# [01:24:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65140
# [1]	validation-logloss:0.61510
# [2]	validation-logloss:0.58745
# [3]	validation-logloss:0.57257
# [4]	validation-logloss:0.55015
# [5]	validation-logloss:0.52999
# [6]	validation-logloss:0.50979
# [7]	validation-logloss:0.49227
# [8]	validation-logloss:0.48212
# [9]	validation-logloss:0.47323
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 79.91%
#
# -------------------------------------------------------------------
#
# [01:24:16] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65563
# [1]	validation-logloss:0.62085
# [2]	validation-logloss:0.59637
# [3]	validation-logloss:0.58120
# [4]	validation-logloss:0.55851
# [5]	validation-logloss:0.54042
# [6]	validation-logloss:0.52443
# [7]	validation-logloss:0.51160
# [8]	validation-logloss:0.50305
# [9]	validation-logloss:0.49473
# Accuracy using DMatrix: 80.58%
# Accuracy using XGBClassifier: 80.13%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65408
# [1]	validation-logloss:0.61798
# [2]	validation-logloss:0.59489
# [3]	validation-logloss:0.58104
# [4]	validation-logloss:0.55740
# [5]	validation-logloss:0.54112
# [6]	validation-logloss:0.52314
# [7]	validation-logloss:0.50739
# [8]	validation-logloss:0.49741
# [9]	validation-logloss:0.48935
# Accuracy using DMatrix: 77.68%
# Accuracy using XGBClassifier: 79.69%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65273
# [1]	validation-logloss:0.61385
# [2]	validation-logloss:0.58601
# [3]	validation-logloss:0.57154
# [4]	validation-logloss:0.54449
# [5]	validation-logloss:0.52700
# [6]	validation-logloss:0.50752
# [7]	validation-logloss:0.48881
# [8]	validation-logloss:0.47883
# [9]	validation-logloss:0.46790
# Accuracy using DMatrix: 82.37%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65449
# [1]	validation-logloss:0.61936
# [2]	validation-logloss:0.59544
# [3]	validation-logloss:0.58094
# [4]	validation-logloss:0.56054
# [5]	validation-logloss:0.54172
# [6]	validation-logloss:0.52394
# [7]	validation-logloss:0.50916
# [8]	validation-logloss:0.49900
# [9]	validation-logloss:0.49142
# Accuracy using DMatrix: 78.79%
# Accuracy using XGBClassifier: 78.79%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65293
# [1]	validation-logloss:0.61823
# [2]	validation-logloss:0.59092
# [3]	validation-logloss:0.57492
# [4]	validation-logloss:0.55216
# [5]	validation-logloss:0.53190
# [6]	validation-logloss:0.51533
# [7]	validation-logloss:0.49988
# [8]	validation-logloss:0.48994
# [9]	validation-logloss:0.47820
# Accuracy using DMatrix: 82.37%
# Accuracy using XGBClassifier: 83.48%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65222
# [1]	validation-logloss:0.61589
# [2]	validation-logloss:0.59077
# [3]	validation-logloss:0.57924
# [4]	validation-logloss:0.55368
# [5]	validation-logloss:0.53350
# [6]	validation-logloss:0.51513
# [7]	validation-logloss:0.49797
# [8]	validation-logloss:0.48952
# [9]	validation-logloss:0.47966
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 81.70%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65209
# [1]	validation-logloss:0.61356
# [2]	validation-logloss:0.58253
# [3]	validation-logloss:0.56768
# [4]	validation-logloss:0.54112
# [5]	validation-logloss:0.52105
# [6]	validation-logloss:0.49930
# [7]	validation-logloss:0.48117
# [8]	validation-logloss:0.46964
# [9]	validation-logloss:0.45701
# Accuracy using DMatrix: 81.03%
# Accuracy using XGBClassifier: 80.13%
#
# -------------------------------------------------------------------
#
# [01:24:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64806
# [1]	validation-logloss:0.60889
# [2]	validation-logloss:0.57833
# [3]	validation-logloss:0.56460
# [4]	validation-logloss:0.53909
# [5]	validation-logloss:0.51761
# [6]	validation-logloss:0.49866
# [7]	validation-logloss:0.48036
# [8]	validation-logloss:0.46742
# [9]	validation-logloss:0.45648
# Accuracy using DMatrix: 79.69%
# Accuracy using XGBClassifier: 80.36%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65174
# [1]	validation-logloss:0.61265
# [2]	validation-logloss:0.58251
# [3]	validation-logloss:0.57009
# [4]	validation-logloss:0.54353
# [5]	validation-logloss:0.52143
# [6]	validation-logloss:0.49999
# [7]	validation-logloss:0.48015
# [8]	validation-logloss:0.46884
# [9]	validation-logloss:0.45774
# Accuracy using DMatrix: 81.70%
# Accuracy using XGBClassifier: 82.14%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64691
# [1]	validation-logloss:0.60827
# [2]	validation-logloss:0.57591
# [3]	validation-logloss:0.55973
# [4]	validation-logloss:0.53553
# [5]	validation-logloss:0.51321
# [6]	validation-logloss:0.49197
# [7]	validation-logloss:0.47346
# [8]	validation-logloss:0.46284
# [9]	validation-logloss:0.45131
# Accuracy using DMatrix: 83.26%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64995
# [1]	validation-logloss:0.61069
# [2]	validation-logloss:0.58294
# [3]	validation-logloss:0.56663
# [4]	validation-logloss:0.54244
# [5]	validation-logloss:0.52207
# [6]	validation-logloss:0.50190
# [7]	validation-logloss:0.48270
# [8]	validation-logloss:0.47205
# [9]	validation-logloss:0.46091
# Accuracy using DMatrix: 82.14%
# Accuracy using XGBClassifier: 82.81%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65349
# [1]	validation-logloss:0.61457
# [2]	validation-logloss:0.58166
# [3]	validation-logloss:0.56982
# [4]	validation-logloss:0.54447
# [5]	validation-logloss:0.52503
# [6]	validation-logloss:0.50434
# [7]	validation-logloss:0.48359
# [8]	validation-logloss:0.47343
# [9]	validation-logloss:0.46074
# Accuracy using DMatrix: 77.23%
# Accuracy using XGBClassifier: 78.35%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65256
# [1]	validation-logloss:0.61350
# [2]	validation-logloss:0.58634
# [3]	validation-logloss:0.57176
# [4]	validation-logloss:0.54482
# [5]	validation-logloss:0.52436
# [6]	validation-logloss:0.50281
# [7]	validation-logloss:0.48554
# [8]	validation-logloss:0.47497
# [9]	validation-logloss:0.46731
# Accuracy using DMatrix: 79.91%
# Accuracy using XGBClassifier: 81.47%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65053
# [1]	validation-logloss:0.61109
# [2]	validation-logloss:0.57959
# [3]	validation-logloss:0.56401
# [4]	validation-logloss:0.53722
# [5]	validation-logloss:0.51619
# [6]	validation-logloss:0.49537
# [7]	validation-logloss:0.47694
# [8]	validation-logloss:0.46457
# [9]	validation-logloss:0.45288
# Accuracy using DMatrix: 81.92%
# Accuracy using XGBClassifier: 81.92%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64969
# [1]	validation-logloss:0.61317
# [2]	validation-logloss:0.58495
# [3]	validation-logloss:0.56964
# [4]	validation-logloss:0.54740
# [5]	validation-logloss:0.52664
# [6]	validation-logloss:0.50762
# [7]	validation-logloss:0.48921
# [8]	validation-logloss:0.47881
# [9]	validation-logloss:0.46772
# Accuracy using DMatrix: 77.68%
# Accuracy using XGBClassifier: 76.79%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65417
# [1]	validation-logloss:0.61697
# [2]	validation-logloss:0.58992
# [3]	validation-logloss:0.57608
# [4]	validation-logloss:0.55275
# [5]	validation-logloss:0.53320
# [6]	validation-logloss:0.51354
# [7]	validation-logloss:0.49556
# [8]	validation-logloss:0.48549
# [9]	validation-logloss:0.47538
# Accuracy using DMatrix: 82.81%
# Accuracy using XGBClassifier: 81.47%
#
# -------------------------------------------------------------------
#
# [01:24:18] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65180
# [1]	validation-logloss:0.61665
# [2]	validation-logloss:0.59025
# [3]	validation-logloss:0.57401
# [4]	validation-logloss:0.55014
# [5]	validation-logloss:0.52856
# [6]	validation-logloss:0.50869
# [7]	validation-logloss:0.49137
# [8]	validation-logloss:0.48066
# [9]	validation-logloss:0.47061
# Accuracy using DMatrix: 79.24%
# Accuracy using XGBClassifier: 79.69%
#
# -------------------------------------------------------------------
#
# [01:24:19] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65235
# [1]	validation-logloss:0.61537
# [2]	validation-logloss:0.58809
# [3]	validation-logloss:0.57614
# [4]	validation-logloss:0.55240
# [5]	validation-logloss:0.53368
# [6]	validation-logloss:0.51396
# [7]	validation-logloss:0.49653
# [8]	validation-logloss:0.48476
# [9]	validation-logloss:0.47439
# Accuracy using DMatrix: 78.79%
# Accuracy using XGBClassifier: 77.90%
#
# -------------------------------------------------------------------
#
# [01:24:19] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65225
# [1]	validation-logloss:0.61440
# [2]	validation-logloss:0.58188
# [3]	validation-logloss:0.56799
# [4]	validation-logloss:0.54226
# [5]	validation-logloss:0.52275
# [6]	validation-logloss:0.49946
# [7]	validation-logloss:0.48059
# [8]	validation-logloss:0.46827
# [9]	validation-logloss:0.45709
# Accuracy using DMatrix: 79.91%
# Accuracy using XGBClassifier: 80.80%
#
# -------------------------------------------------------------------
#
# [01:24:19] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65463
# [1]	validation-logloss:0.61878
# [2]	validation-logloss:0.59308
# [3]	validation-logloss:0.57918
# [4]	validation-logloss:0.55672
# [5]	validation-logloss:0.53950
# [6]	validation-logloss:0.52215
# [7]	validation-logloss:0.50633
# [8]	validation-logloss:0.49475
# [9]	validation-logloss:0.48479
# Accuracy using DMatrix: 79.46%
# Accuracy using XGBClassifier: 81.25%
#
# -------------------------------------------------------------------
#
# [01:24:19] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.65465
# [1]	validation-logloss:0.62011
# [2]	validation-logloss:0.59396
# [3]	validation-logloss:0.58171
# [4]	validation-logloss:0.55955
# [5]	validation-logloss:0.54068
# [6]	validation-logloss:0.52427
# [7]	validation-logloss:0.50887
# [8]	validation-logloss:0.49866
# [9]	validation-logloss:0.48881
# Accuracy using DMatrix: 79.91%
# Accuracy using XGBClassifier: 81.03%
#
# -------------------------------------------------------------------
#
# [01:24:19] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.64932
# [1]	validation-logloss:0.60993
# [2]	validation-logloss:0.58264
# [3]	validation-logloss:0.56696
# [4]	validation-logloss:0.54137
# [5]	validation-logloss:0.51844
# [6]	validation-logloss:0.49615
# [7]	validation-logloss:0.47712
# [8]	validation-logloss:0.46529
# [9]	validation-logloss:0.45483
# Accuracy using DMatrix: 80.13%
# Accuracy using XGBClassifier: 80.36%
# 0.8109598214285714
# 0.8069196428571429
