# %%
import os
import pandas as pd
import numpy as np
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
current_directory = 'C:\\Users\\Atit Acharya\\OneDrive - The University of Texas at Tyler\\Desktop\\Research\\Classification\\XGBOOST'
# print(current_directory)

acc_XGB = []
acc_DMat = []
for filename in os.listdir(current_directory):
#     print(filename)
    if os.path.isfile(os.path.join(current_directory, filename)) and '.csv' in filename:
#         # Do something with the file
        print("\n-------------------------------------------------------------------\n")
        data = pd.read_csv(filename)
        train, test = train_test_split(data, test_size=0.1, random_state=42)
        train, val = train_test_split(train, test_size=0.1, random_state=42)
        
        
        X_train = train.drop(['LastStatementMinimumPaymentDueAmount', 'CardExternalStatus','Target'] , axis=1)
#         X_train = train.drop('Target', axis=1)
        y_train = train['Target']
        
        
        X_val = val.drop(['LastStatementMinimumPaymentDueAmount' , 'CardExternalStatus', 'Target'] , axis=1)
#         X_val = val.drop('Target', axis=1)
        y_val = val['Target']
        
        X_test = test.drop(['LastStatementMinimumPaymentDueAmount', 'CardExternalStatus', 'Target'] , axis=1)
#         X_test = test.drop('Target', axis=1)
        y_test = test['Target']
        
        params = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'max_depth': 10,
            'learning_rate': 0.1,
            'n_estimators': 100,
             'gamma' : 0.1,
            'reg_alpha' : 0.1,
            'reg_lamdba':0.1
        }
        
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dval = xgb.DMatrix(X_val, label=y_val)
        
        model = xgb.train(params, dtrain, evals=[(dval, 'validation')], early_stopping_rounds=10)
        
        dtest = xgb.DMatrix(X_test)
        
        y_pred = model.predict(dtest)
        y_pred = np.round(y_pred)
        
        Dmatrix_accuracy = accuracy_score(y_test, y_pred)
        
        print('Accuracy using DMatrix: {:.2f}%'.format(Dmatrix_accuracy * 100))
        
        # initialize the XGBClassifier model with pruning parameters
        clf = XGBClassifier(
            max_depth=3,          # Maximum tree depth
            learning_rate=0.1,    # Learning rate
#             n_estimators=100,     # Number of trees in the forest
            gamma=0.1,            # Minimum loss reduction to make a further partition
            reg_alpha=0.1,        # L1 regularization on leaf weights
#             reg_lambda=0.1,       # L2 regularization on leaf weights
            subsample=0.8,        # Subsample ratio of the training set
            colsample_bytree=0.8  # Subsample ratio of columns when constructing each tree
        )
        
        # train the XGBClassifier model on the training set
        clf.fit(X_train, y_train)
        
        # evaluate the accuracy of the model on the testing set
        XGBClassifier_accuracy = clf.score(X_test, y_test)
        print("Accuracy using XGBClassifier: %.2f%%" % (XGBClassifier_accuracy * 100.0))

        acc_XGB.append(XGBClassifier_accuracy)
        acc_DMat.append(Dmatrix_accuracy)

Average_XGBClassifier = np.mean(acc_XGB)
print(Average_XGBClassifier)

Average_DMatrix = np.mean(acc_DMat)
print(Average_DMatrix)
# Out:
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61178
# [1]	validation-logloss:0.57469
# [2]	validation-logloss:0.53570
# [3]	validation-logloss:0.48153
# [4]	validation-logloss:0.45901
# [5]	validation-logloss:0.41638
# [6]	validation-logloss:0.39215
# [7]	validation-logloss:0.37290
# [8]	validation-logloss:0.34165
# [9]	validation-logloss:0.31630
# Accuracy using DMatrix: 95.54%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61212
# [1]	validation-logloss:0.57229
# [2]	validation-logloss:0.52936
# [3]	validation-logloss:0.47416
# [4]	validation-logloss:0.45005
# [5]	validation-logloss:0.40629
# [6]	validation-logloss:0.38076
# [7]	validation-logloss:0.35966
# [8]	validation-logloss:0.32860
# [9]	validation-logloss:0.30221
# Accuracy using DMatrix: 95.31%
# Accuracy using XGBClassifier: 95.76%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61144
# [1]	validation-logloss:0.57336
# [2]	validation-logloss:0.53297
# [3]	validation-logloss:0.47906
# [4]	validation-logloss:0.45671
# [5]	validation-logloss:0.41321
# [6]	validation-logloss:0.38778
# [7]	validation-logloss:0.36740
# [8]	validation-logloss:0.33650
# [9]	validation-logloss:0.31019
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61422
# [1]	validation-logloss:0.57511
# [2]	validation-logloss:0.53137
# [3]	validation-logloss:0.47756
# [4]	validation-logloss:0.45237
# [5]	validation-logloss:0.41055
# [6]	validation-logloss:0.38510
# [7]	validation-logloss:0.36341
# [8]	validation-logloss:0.33443
# [9]	validation-logloss:0.30957
# Accuracy using DMatrix: 96.65%
# Accuracy using XGBClassifier: 97.32%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61295
# [1]	validation-logloss:0.57619
# [2]	validation-logloss:0.53269
# [3]	validation-logloss:0.47893
# [4]	validation-logloss:0.45512
# [5]	validation-logloss:0.41379
# [6]	validation-logloss:0.38792
# [7]	validation-logloss:0.36808
# [8]	validation-logloss:0.33913
# [9]	validation-logloss:0.31373
# Accuracy using DMatrix: 96.65%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61543
# [1]	validation-logloss:0.57644
# [2]	validation-logloss:0.53645
# [3]	validation-logloss:0.48461
# [4]	validation-logloss:0.45938
# [5]	validation-logloss:0.41883
# [6]	validation-logloss:0.39423
# [7]	validation-logloss:0.37717
# [8]	validation-logloss:0.34854
# [9]	validation-logloss:0.32388
# Accuracy using DMatrix: 96.21%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:42] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61281
# [1]	validation-logloss:0.57293
# [2]	validation-logloss:0.53122
# [3]	validation-logloss:0.47790
# [4]	validation-logloss:0.45260
# [5]	validation-logloss:0.41077
# [6]	validation-logloss:0.38499
# [7]	validation-logloss:0.36547
# [8]	validation-logloss:0.33502
# [9]	validation-logloss:0.30931
# Accuracy using DMatrix: 94.20%
# Accuracy using XGBClassifier: 94.87%
#
# -------------------------------------------------------------------
#
# [00:42:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61335
# [1]	validation-logloss:0.57498
# [2]	validation-logloss:0.53301
# [3]	validation-logloss:0.48035
# [4]	validation-logloss:0.45591
# [5]	validation-logloss:0.41410
# [6]	validation-logloss:0.39005
# [7]	validation-logloss:0.36881
# [8]	validation-logloss:0.33849
# [9]	validation-logloss:0.31365
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 97.54%
#
# -------------------------------------------------------------------
#
# [00:42:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61146
# [1]	validation-logloss:0.57143
# [2]	validation-logloss:0.52855
# [3]	validation-logloss:0.47427
# [4]	validation-logloss:0.45010
# [5]	validation-logloss:0.40695
# [6]	validation-logloss:0.37979
# [7]	validation-logloss:0.35949
# [8]	validation-logloss:0.32921
# [9]	validation-logloss:0.30326
# Accuracy using DMatrix: 94.64%
# Accuracy using XGBClassifier: 95.54%
#
# -------------------------------------------------------------------
#
# [00:42:43] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61094
# [1]	validation-logloss:0.56989
# [2]	validation-logloss:0.52659
# [3]	validation-logloss:0.47237
# [4]	validation-logloss:0.44802
# [5]	validation-logloss:0.40492
# [6]	validation-logloss:0.37890
# [7]	validation-logloss:0.35828
# [8]	validation-logloss:0.32752
# [9]	validation-logloss:0.30165
# Accuracy using DMatrix: 96.65%
# Accuracy using XGBClassifier:
# Accuracy using DMatrix: 96.43%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61353
# [1]	validation-logloss:0.57407
# [2]	validation-logloss:0.53243
# [3]	validation-logloss:0.47862
# [4]	validation-logloss:0.45402
# [5]	validation-logloss:0.41140
# [6]	validation-logloss:0.38524
# [7]	validation-logloss:0.36472
# [8]	validation-logloss:0.33455
# [9]	validation-logloss:0.30873
# Accuracy using DMatrix: 96.43%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61095
# [1]	validation-logloss:0.57041
# [2]	validation-logloss:0.53090
# [3]	validation-logloss:0.47666
# [4]	validation-logloss:0.45371
# [5]	validation-logloss:0.41002
# [6]	validation-logloss:0.38487
# [7]	validation-logloss:0.36571
# [8]	validation-logloss:0.33514
# [9]	validation-logloss:0.30943
# Accuracy using DMatrix: 97.54%
# Accuracy using XGBClassifier: 97.54%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61401
# [1]	validation-logloss:0.57746
# [2]	validation-logloss:0.53682
# [3]	validation-logloss:0.48425
# [4]	validation-logloss:0.46112
# [5]	validation-logloss:0.41930
# [6]	validation-logloss:0.39329
# [7]	validation-logloss:0.37452
# [8]	validation-logloss:0.34560
# [9]	validation-logloss:0.31981
# Accuracy using DMatrix: 97.10%
# Accuracy using XGBClassifier: 97.54%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61510
# [1]	validation-logloss:0.57606
# [2]	validation-logloss:0.53163
# [3]	validation-logloss:0.47939
# [4]	validation-logloss:0.45423
# [5]	validation-logloss:0.41287
# [6]	validation-logloss:0.38764
# [7]	validation-logloss:0.36733
# [8]	validation-logloss:0.33815
# [9]	validation-logloss:0.31394
# Accuracy using DMatrix: 95.09%
# Accuracy using XGBClassifier: 96.88%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61349
# [1]	validation-logloss:0.57208
# [2]	validation-logloss:0.52858
# [3]	validation-logloss:0.47723
# [4]	validation-logloss:0.45183
# [5]	validation-logloss:0.41016
# [6]	validation-logloss:0.38300
# [7]	validation-logloss:0.36222
# [8]	validation-logloss:0.33291
# [9]	validation-logloss:0.30759
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61511
# [1]	validation-logloss:0.57777
# [2]	validation-logloss:0.53626
# [3]	validation-logloss:0.48384
# [4]	validation-logloss:0.45968
# [5]	validation-logloss:0.41971
# [6]	validation-logloss:0.39549
# [7]	validation-logloss:0.37679
# [8]	validation-logloss:0.34847
# [9]	validation-logloss:0.32538
# Accuracy using DMatrix: 93.97%
# Accuracy using XGBClassifier: 95.09%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61642
# [1]	validation-logloss:0.57876
# [2]	validation-logloss:0.54042
# [3]	validation-logloss:0.48846
# [4]	validation-logloss:0.46575
# [5]	validation-logloss:0.42472
# [6]	validation-logloss:0.40012
# [7]	validation-logloss:0.38252
# [8]	validation-logloss:0.35374
# [9]	validation-logloss:0.32939
# Accuracy using DMatrix: 96.43%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:44] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61399
# [1]	validation-logloss:0.57694
# [2]	validation-logloss:0.53717
# [3]	validation-logloss:0.48239
# [4]	validation-logloss:0.46074
# [5]	validation-logloss:0.41746
# [6]	validation-logloss:0.39288
# [7]	validation-logloss:0.37432
# [8]	validation-logloss:0.34444
# [9]	validation-logloss:0.31976
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 96.43%
#
# -------------------------------------------------------------------
#
# [00:42:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61093
# [1]	validation-logloss:0.56976
# [2]	validation-logloss:0.52920
# [3]	validation-logloss:0.47499
# [4]	validation-logloss:0.45134
# [5]	validation-logloss:0.40779
# [6]	validation-logloss:0.38147
# [7]	validation-logloss:0.36290
# [8]	validation-logloss:0.33227
# [9]	validation-logloss:0.30524
# Accuracy using DMatrix: 96.65%
# Accuracy using XGBClassifier: 96.88%
#
# -------------------------------------------------------------------
#
# [00:42:45] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.
# Accuracy using DMatrix: 95.31%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:47] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61605
# [1]	validation-logloss:0.57693
# [2]	validation-logloss:0.53806
# [3]	validation-logloss:0.48479
# [4]	validation-logloss:0.46290
# [5]	validation-logloss:0.42108
# [6]	validation-logloss:0.39582
# [7]	validation-logloss:0.37838
# [8]	validation-logloss:0.34828
# [9]	validation-logloss:0.32129
# Accuracy using DMatrix: 94.87%
# Accuracy using XGBClassifier: 95.76%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61317
# [1]	validation-logloss:0.57538
# [2]	validation-logloss:0.53573
# [3]	validation-logloss:0.48182
# [4]	validation-logloss:0.45739
# [5]	validation-logloss:0.41493
# [6]	validation-logloss:0.39090
# [7]	validation-logloss:0.37251
# [8]	validation-logloss:0.34323
# [9]	validation-logloss:0.31722
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 96.43%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61305
# [1]	validation-logloss:0.57290
# [2]	validation-logloss:0.53330
# [3]	validation-logloss:0.48066
# [4]	validation-logloss:0.45685
# [5]	validation-logloss:0.41610
# [6]	validation-logloss:0.39220
# [7]	validation-logloss:0.37224
# [8]	validation-logloss:0.34341
# [9]	validation-logloss:0.31841
# Accuracy using DMatrix: 96.88%
# Accuracy using XGBClassifier: 97.99%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61370
# [1]	validation-logloss:0.57571
# [2]	validation-logloss:0.53531
# [3]	validation-logloss:0.48320
# [4]	validation-logloss:0.45922
# [5]	validation-logloss:0.41684
# [6]	validation-logloss:0.39040
# [7]	validation-logloss:0.37195
# [8]	validation-logloss:0.34310
# [9]	validation-logloss:0.31725
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 96.88%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61451
# [1]	validation-logloss:0.57434
# [2]	validation-logloss:0.53311
# [3]	validation-logloss:0.47980
# [4]	validation-logloss:0.45538
# [5]	validation-logloss:0.41452
# [6]	validation-logloss:0.38886
# [7]	validation-logloss:0.36945
# [8]	validation-logloss:0.34135
# [9]	validation-logloss:0.31753
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61201
# [1]	validation-logloss:0.57361
# [2]	validation-logloss:0.53295
# [3]	validation-logloss:0.47870
# [4]	validation-logloss:0.45477
# [5]	validation-logloss:0.41134
# [6]	validation-logloss:0.38638
# [7]	validation-logloss:0.36685
# [8]	validation-logloss:0.33595
# [9]	validation-logloss:0.30979
# Accuracy using DMatrix: 95.54%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61502
# [1]	validation-logloss:0.57634
# [2]	validation-logloss:0.53484
# [3]	validation-logloss:0.48373
# [4]	validation-logloss:0.45990
# [5]	validation-logloss:0.41976
# [6]	validation-logloss:0.39397
# [7]	validation-logloss:0.37413
# [8]	validation-logloss:0.34600
# [9]	validation-logloss:0.32135
# Accuracy using DMatrix: 95.54%
# Accuracy using XGBClassifier: 94.87%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61414
# [1]	validation-logloss:0.57668
# [2]	validation-logloss:0.53514
# [3]	validation-logloss:0.48122
# [4]	validation-logloss:0.45790
# [5]	validation-logloss:0.41498
# [6]	validation-logloss:0.39044
# [7]	validation-logloss:0.37038
# [8]	validation-logloss:0.34082
# [9]	validation-logloss:0.31551
# Accuracy using DMatrix: 96.88%
# Accuracy using XGBClassifier: 97.32%
#
# -------------------------------------------------------------------
#
# [00:42:48] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 96.43%
#
# -------------------------------------------------------------------
#
# ...
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61290
# [1]	validation-logloss:0.57097
# [2]	validation-logloss:0.52821
# [3]	validation-logloss:0.47502
# [4]	validation-logloss:0.45085
# [5]	validation-logloss:0.40951
# [6]	validation-logloss:0.38552
# [7]	validation-logloss:0.36648
# [8]	validation-logloss:0.33751
# [9]	validation-logloss:0.31156
# Accuracy using DMatrix: 96.21%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61213
# [1]	validation-logloss:0.57319
# [2]	validation-logloss:0.53346
# [3]	validation-logloss:0.47846
# [4]	validation-logloss:0.45518
# [5]	validation-logloss:0.41200
# [6]	validation-logloss:0.38690
# [7]	validation-logloss:0.36627
# [8]	validation-logloss:0.33579
# [9]	validation-logloss:0.31037
# Accuracy using DMatrix: 94.20%
# Accuracy using XGBClassifier: 94.87%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61551
# [1]	validation-logloss:0.58043
# [2]	validation-logloss:0.54166
# [3]	validation-logloss:0.48811
# [4]	validation-logloss:0.46860
# [5]	validation-logloss:0.42695
# [6]	validation-logloss:0.40212
# [7]	validation-logloss:0.38384
# [8]	validation-logloss:0.35435
# [9]	validation-logloss:0.32881
# Accuracy using DMatrix: 95.09%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61471
# [1]	validation-logloss:0.57966
# [2]	validation-logloss:0.54152
# [3]	validation-logloss:0.48717
# [4]	validation-logloss:0.46605
# [5]	validation-logloss:0.42423
# [6]	validation-logloss:0.40058
# [7]	validation-logloss:0.38174
# [8]	validation-logloss:0.35207
# [9]	validation-logloss:0.32582
# Accuracy using DMatrix: 94.64%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61521
# [1]	validation-logloss:0.57699
# [2]	validation-logloss:0.53618
# [3]	validation-logloss:0.48523
# [4]	validation-logloss:0.46060
# [5]	validation-logloss:0.42022
# [6]	validation-logloss:0.39485
# [7]	validation-logloss:0.37437
# [8]	validation-logloss:0.34698
# [9]	validation-logloss:0.32342
# Accuracy using DMatrix: 95.09%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61434
# [1]	validation-logloss:0.57840
# [2]	validation-logloss:0.54029
# [3]	validation-logloss:0.48639
# [4]	validation-logloss:0.46506
# [5]	validation-logloss:0.42152
# [6]	validation-logloss:0.39762
# [7]	validation-logloss:0.37895
# [8]	validation-logloss:0.34821
# [9]	validation-logloss:0.32163
# Accuracy using DMatrix: 96.21%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61778
# [1]	validation-logloss:0.58182
# [2]	validation-logloss:0.54064
# [3]	validation-logloss:0.49193
# [4]	validation-logloss:0.47074
# [5]	validation-logloss:0.43116
# [6]	validation-logloss:0.40770
# [7]	validation-logloss:0.38856
# [8]	validation-logloss:0.35986
# [9]	validation-logloss:0.33624
# Accuracy using DMatrix: 97.54%
# Accuracy using XGBClassifier: 97.32%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61436
# [1]	validation-logloss:0.57874
# [2]	validation-logloss:0.53717
# [3]	validation-logloss:0.48503
# [4]	validation-logloss:0.46269
# [5]	validation-logloss:0.42002
# [6]	validation-logloss:0.39535
# [7]	validation-logloss:0.37618
# [8]	validation-logloss:0.34714
# [9]	validation-logloss:0.32256
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61201
# [1]	validation-logloss:0.57070
# [2]	validation-logloss:0.52879
# [3]	validation-logloss:0.47394
# [4]	validation-logloss:0.44852
# [5]	validation-logloss:0.40527
# [6]	validation-logloss:0.38097
# [7]	validation-logloss:0.36257
# [8]	validation-logloss:0.33200
# [9]	validation-logloss:0.30508
# Accuracy using DMatrix: 94.87%
# Accuracy using XGBClassifier: 95.76%
#
# -------------------------------------------------------------------
#
# [00:42:50] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61345
# [1]	validation-logloss:0.57304
# [2]	validation-logloss:0.53041
# [3]	validation-logloss:0.47699
# [4]	validation-logloss:0.45311
# [5]	validation-logloss:0.41091
# [6]	validation-logloss:0.38679
# [7]	validation-logloss:0.36664
# [8]	validation-logloss:0.33671
# [9]	validation-logloss:0.31190
# Accuracy using DMatrix: 97.10%
# Accuracy using XGBClassifier: 96.88%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61365
# [1]	validation-logloss:0.57216
# [2]	validation-logloss:0.53023
# [3]	validation-logloss:0.47623
# [4]	validation-logloss:0.44989
# [5]	validation-logloss:0.40807
# [6]	validation-logloss:0.38230
# [7]	validation-logloss:0.36317
# [8]	validation-logloss:0.33249
# [9]	validation-logloss:0.30718
# Accuracy using DMatrix: 96.21%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61224
# [1]	validation-logloss:0.57166
# [2]	validation-logloss:0.52846
# [3]	validation-logloss:0.47453
# [4]	validation-logloss:0.45065
# [5]	validation-logloss:0.40936
# [6]	validation-logloss:0.38280
# [7]	validation-logloss:0.36195
# [8]	validation-logloss:0.33247
# [9]	validation-logloss:0.30791
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 95.31%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61407
# [1]	validation-logloss:0.57343
# [2]	validation-logloss:0.52987
# [3]	validation-logloss:0.47723
# [4]	validation-logloss:0.45327
# [5]	validation-logloss:0.41174
# [6]	validation-logloss:0.38647
# [7]	validation-logloss:0.36484
# [8]	validation-logloss:0.33594
# [9]	validation-logloss:0.31118
# Accuracy using DMatrix: 96.88%
# Accuracy using XGBClassifier: 97.10%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61564
# [1]	validation-logloss:0.57468
# [2]	validation-logloss:0.53457
# [3]	validation-logloss:0.48137
# [4]	validation-logloss:0.45622
# [5]	validation-logloss:0.41358
# [6]	validation-logloss:0.38921
# [7]	validation-logloss:0.36963
# [8]	validation-logloss:0.33963
# [9]	validation-logloss:0.31523
# Accuracy using DMatrix: 95.76%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61312
# [1]	validation-logloss:0.57467
# [2]	validation-logloss:0.53274
# [3]	validation-logloss:0.47773
# [4]	validation-logloss:0.45231
# [5]	validation-logloss:0.40982
# [6]	validation-logloss:0.38421
# [7]	validation-logloss:0.36481
# [8]	validation-logloss:0.33482
# [9]	validation-logloss:0.30924
# Accuracy using DMatrix: 94.64%
# Accuracy using XGBClassifier: 95.98%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61446
# [1]	validation-logloss:0.57284
# [2]	validation-logloss:0.53151
# [3]	validation-logloss:0.47993
# [4]	validation-logloss:0.45595
# [5]	validation-logloss:0.41506
# [6]	validation-logloss:0.39089
# [7]	validation-logloss:0.37101
# [8]	validation-logloss:0.34274
# [9]	validation-logloss:0.31846
# Accuracy using DMatrix: 95.54%
# Accuracy using XGBClassifier: 95.76%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61182
# [1]	validation-logloss:0.57624
# [2]	validation-logloss:0.53471
# [3]	validation-logloss:0.47988
# [4]	validation-logloss:0.45715
# [5]	validation-logloss:0.41470
# [6]	validation-logloss:0.39117
# [7]	validation-logloss:0.37197
# [8]	validation-logloss:0.34063
# [9]	validation-logloss:0.31386
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 96.65%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61563
# [1]	validation-logloss:0.57943
# [2]	validation-logloss:0.53710
# [3]	validation-logloss:0.48456
# [4]	validation-logloss:0.46346
# [5]	validation-logloss:0.42190
# [6]	validation-logloss:0.39627
# [7]	validation-logloss:0.37607
# [8]	validation-logloss:0.34700
# [9]	validation-logloss:0.32183
# Accuracy using DMatrix: 95.98%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61635
# [1]	validation-logloss:0.57761
# [2]	validation-logloss:0.53801
# [3]	validation-logloss:0.48422
# [4]	validation-logloss:0.46279
# [5]	validation-logloss:0.41974
# [6]	validation-logloss:0.39483
# [7]	validation-logloss:0.37542
# [8]	validation-logloss:0.34457
# [9]	validation-logloss:0.31952
# Accuracy using DMatrix: 94.42%
# Accuracy using XGBClassifier: 95.54%
#
# -------------------------------------------------------------------
#
# [00:42:51] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61460
# [1]	validation-logloss:0.57636
# [2]	validation-logloss:0.53626
# [3]	validation-logloss:0.48304
# [4]	validation-logloss:0.46080
# [5]	validation-logloss:0.41859
# [6]	validation-logloss:0.39284
# [7]	validation-logloss:0.37252
# [8]	validation-logloss:0.34373
# [9]	validation-logloss:0.31787
# Accuracy using DMatrix: 96.65%
# Accuracy using XGBClassifier: 97.32%
#
# -------------------------------------------------------------------
#
# [00:42:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61633
# [1]	validation-logloss:0.57583
# [2]	validation-logloss:0.53369
# [3]	validation-logloss:0.48288
# [4]	validation-logloss:0.45606
# [5]	validation-logloss:0.41525
# [6]	validation-logloss:0.38964
# [7]	validation-logloss:0.37164
# [8]	validation-logloss:0.34292
# [9]	validation-logloss:0.31789
# Accuracy using DMatrix: 95.09%
# Accuracy using XGBClassifier: 96.43%
#
# -------------------------------------------------------------------
#
# [00:42:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61651
# [1]	validation-logloss:0.57921
# [2]	validation-logloss:0.54146
# [3]	validation-logloss:0.48900
# [4]	validation-logloss:0.46612
# [5]	validation-logloss:0.42389
# [6]	validation-logloss:0.39976
# [7]	validation-logloss:0.38224
# [8]	validation-logloss:0.35278
# [9]	validation-logloss:0.32651
# Accuracy using DMatrix: 96.43%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61679
# [1]	validation-logloss:0.58156
# [2]	validation-logloss:0.54444
# [3]	validation-logloss:0.49018
# [4]	validation-logloss:0.47001
# [5]	validation-logloss:0.42830
# [6]	validation-logloss:0.40444
# [7]	validation-logloss:0.38754
# [8]	validation-logloss:0.35762
# [9]	validation-logloss:0.33203
# Accuracy using DMatrix: 95.31%
# Accuracy using XGBClassifier: 96.21%
#
# -------------------------------------------------------------------
#
# [00:42:52] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimators", "reg_lamdba" } are not used.
#
# [0]	validation-logloss:0.61488
# [1]	validation-logloss:0.57494
# [2]	validation-logloss:0.53182
# [3]	validation-logloss:0.48010
# [4]	validation-logloss:0.45631
# [5]	validation-logloss:0.41435
# [6]	validation-logloss:0.38820
# [7]	validation-logloss:0.36899
# [8]	validation-logloss:0.33953
# [9]	validation-logloss:0.31476
# Accuracy using DMatrix: 95.54%
# Accuracy using XGBClassifier: 96.21%
# 0.9646428571428569
# 0.9585714285714285
