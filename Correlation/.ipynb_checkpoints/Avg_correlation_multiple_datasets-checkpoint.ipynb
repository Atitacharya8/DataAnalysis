# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr
import numpy as np
import os

# %%
Tot_corr1 = []
Tot_corr2 = []
current_directory = 'C:\\Users\\Atit Acharya\\OneDrive - The University of Texas at Tyler\\Desktop\\Research\\Classification\\XGBOOST'
# print(current_directory)
for filename in os.listdir(current_directory):
    #     print(filename)
    if os.path.isfile(os.path.join(current_directory, filename)) and '.csv' in filename:
       # Do something with the file
            print("\n-----------------------------------------------------------------\n")
            # Load the dataset
            data = pd.read_csv(filename)
            data = data.drop(['Unnamed: 0'], axis =1)
            
            # calculate Pearson correlation coefficient
            corr1, _ = pearsonr(data['CardExternalStatus'], pd.Categorical(data['Target']).codes)
            print('Pearson correlation coefficient:', corr1)
            
            # calculate Spearman rank correlation coefficient
            corr2, _ = spearmanr(data['CardExternalStatus'], pd.Categorical(data['Target']).codes)
            print('Spearman rank correlation coefficient:', corr2)
            
            Tot_corr1.append(corr1)
            Tot_corr2.append(corr2)
            
Average_Pearson = np.mean(Tot_corr1)
print("Average Pearson correlation: %.2f" % Average_Pearson)

Average_Spearman = np.mean(Tot_corr2)
print("Average Spearman correlation: %.2f" % Average_Spearman)
# Out:
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5304209216318991
# Spearman rank correlation coefficient: 0.5539006907025709
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5121584910573973
# Spearman rank correlation coefficient: 0.5405040047591803
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5157215001426688
# Spearman rank correlation coefficient: 0.540498896569321
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5161631168106917
# Spearman rank correlation coefficient: 0.5437222931149515
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5238217278046886
# Spearman rank correlation coefficient: 0.5475738431767883
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5079442737098006
# Spearman rank correlation coefficient: 0.5366546933393557
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5160907434964903
# Spearman rank correlation coefficient: 0.5420808791468851
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5036605108621912
# Spearman rank correlation coefficient: 0.5323049208430964
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5278773525135521
# Spearman rank correlation coefficient: 0.5532534486471422
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5238624069719258
# Spearman rank correlation coefficient: 0.5489354440507707
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5180346414871885
# Spearman rank correlation coefficient: 0.5437339142730971
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5145619515977116
# Spearman rank correlation coefficient: 0.5390681133887449
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5100674399727152
# Spearman rank correlation coefficient: 0.5369897685613596
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5108665471401266
# Spearman rank correlation coefficient: 0.536965561740841
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5249673687065501
# Spearman rank correlation coefficient: 0.5512628824727953
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5332074568487098
# Spearman rank correlation coefficient: 0.5569029942571202
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.527216209514674
# Spearman rank correlation coefficient: 0.5496008839289426
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5288136639952548
# Spearman rank correlation coefficient: 0.5528867840091428
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5054960976280456
# Spearman rank correlation coefficient: 0.535503159640191
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5386432278098507
# Spearman rank correlation coefficient: 0.5615081851310989
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5164871514412708
# Spearman rank correlation coefficient: 0.5416556778727396
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5153488305526776
# Spearman rank correlation coefficient: 0.540024886295977
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5152027764206042
# Spearman rank correlation coefficient: 0.542502097637244
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5017095989547546
# Spearman rank correlation coefficient: 0.5325011628422314
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.504566387979959
# Spearman rank correlation coefficient: 0.5325832359696536
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5105616304365626
# Spearman rank correlation coefficient: 0.5389936923891747
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5387386129929813
# Spearman rank correlation coefficient: 0.5602852958818162
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5275701667778193
# Spearman rank correlation coefficient: 0.5519197952543046
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5240301137285368
# Spearman rank correlation coefficient: 0.5508772099625411
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5010868544603349
# Spearman rank correlation coefficient: 0.5306663478924766
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5153732116233118
# Spearman rank correlation coefficient: 0.5412703940565289
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.528006742484054
# Spearman rank correlation coefficient: 0.5508652268905465
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5357355912412388
# Spearman rank correlation coefficient: 0.5577869861333578
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5180104470171009
# Spearman rank correlation coefficient: 0.5422295176699065
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.531855540540782
# Spearman rank correlation coefficient: 0.5573221459896511
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5243442704466071
# Spearman rank correlation coefficient: 0.5520450415551582
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5206141467766405
# Spearman rank correlation coefficient: 0.5443645199109417
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5173644081313774
# Spearman rank correlation coefficient: 0.5406586027848702
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5124542538246468
# Spearman rank correlation coefficient: 0.5378964079896663
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5057220941630323
# Spearman rank correlation coefficient: 0.5333704590405427
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5288951317845609
# Spearman rank correlation coefficient: 0.5534853904796718
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5189416407794144
# Spearman rank correlation coefficient: 0.54386129865261
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5091757722291836
# Spearman rank correlation coefficient: 0.5347796538144176
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5235916169833932
# Spearman rank correlation coefficient: 0.5484892086927166
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.49939787361733456
# Spearman rank correlation coefficient: 0.5263633188229848
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5095741412132929
# Spearman rank correlation coefficient: 0.5370598118039899
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5197804596793943
# Spearman rank correlation coefficient: 0.5439166204248548
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5166234125523084
# Spearman rank correlation coefficient: 0.543053431919974
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5222816638976046
# Spearman rank correlation coefficient: 0.5468304088291053
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5229301635305997
# Spearman rank correlation coefficient: 0.5469204875417496
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5231293615111461
# Spearman rank correlation coefficient: 0.5436626344456567
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5177688812128491
# Spearman rank correlation coefficient: 0.5442096756190113
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5223641944815963
# Spearman rank correlation coefficient: 0.5471237082464023
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5107079026530836
# Spearman rank correlation coefficient: 0.5389260150996817
#
# -----------------------------------------------------------------
# Pearson correlation coefficient: 0.5131764336541997
# Spearman rank correlation coefficient: 0.5395512547936128
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5227605642023445
# Spearman rank correlation coefficient: 0.546249549072615
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.521905024950525
# Spearman rank correlation coefficient: 0.5441519890051254
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5259296786997765
# Spearman rank correlation coefficient: 0.5502829597097095
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5342560961421076
# Spearman rank correlation coefficient: 0.5600779501183109
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5210928399687316
# Spearman rank correlation coefficient: 0.5449957039911768
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5307509436417721
# Spearman rank correlation coefficient: 0.553510507334115
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5220507828031209
# Spearman rank correlation coefficient: 0.5476335007171935
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5172428475685862
# Spearman rank correlation coefficient: 0.5409838695631188
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5235704787548974
# Spearman rank correlation coefficient: 0.5461922151712434
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5189539006688949
# Spearman rank correlation coefficient: 0.5467167104407775
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5029875881247547
# Spearman rank correlation coefficient: 0.5327558143962503
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5338296481690098
# Spearman rank correlation coefficient: 0.5569465458597013
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5100141535065038
# Spearman rank correlation coefficient: 0.5377202239422553
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5339400014622793
# Spearman rank correlation coefficient: 0.5560649315386518
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5286124066774744
# Spearman rank correlation coefficient: 0.5535849361566365
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5041606604499265
# Spearman rank correlation coefficient: 0.5312634549473795
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5200923251208465
# Spearman rank correlation coefficient: 0.5459959120866565
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5285159994805047
# Spearman rank correlation coefficient: 0.5546959944799547
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5318711183018787
# Spearman rank correlation coefficient: 0.5580724949465051
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5049390400500897
# Spearman rank correlation coefficient: 0.5343910077800077
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5132178716795828
# Spearman rank correlation coefficient: 0.5370553907191158
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5083548757420906
# Spearman rank correlation coefficient: 0.5389195765389317
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5169290978440286
# Spearman rank correlation coefficient: 0.540845250877239
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5090900532923484
# Spearman rank correlation coefficient: 0.5341545312137338
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5331756183226559
# Spearman rank correlation coefficient: 0.5543679229402887
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5292314039631685
# Spearman rank correlation coefficient: 0.5521224415062809
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5057186990047856
# Spearman rank correlation coefficient: 0.5333994597011152
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.505532085870277
# Spearman rank correlation coefficient: 0.5353704673160709
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5333737986225943
# Spearman rank correlation coefficient: 0.5569517655532685
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5287057772025372
# Spearman rank correlation coefficient: 0.5557654870291218
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5066949651680382
# Spearman rank correlation coefficient: 0.5346108850898077
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5179989155546271
# Spearman rank correlation coefficient: 0.5438569963785852
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5240996294299265
# Spearman rank correlation coefficient: 0.5465277577904284
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5068659920132399
# Spearman rank correlation coefficient: 0.5351094537630826
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.49704083345643446
# Spearman rank correlation coefficient: 0.526024802093182
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5464115558433383
# Spearman rank correlation coefficient: 0.5704294009816201
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5133410535080163
# Spearman rank correlation coefficient: 0.5411460233387786
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5152426204201824
# Spearman rank correlation coefficient: 0.539969608227974
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.52170709445636
# Spearman rank correlation coefficient: 0.5462908859802126
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5334555912259072
# Spearman rank correlation coefficient: 0.5584467205146986
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5207804905755191
# Spearman rank correlation coefficient: 0.5439289295673343
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5126004377016959
# Spearman rank correlation coefficient: 0.5409210890186517
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.4989257519458077
# Spearman rank correlation coefficient: 0.5300332318050529
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.516905058186238
# Spearman rank correlation coefficient: 0.5428655759046328
#
# -----------------------------------------------------------------
#
# Pearson correlation coefficient: 0.5157369883001461
# Spearman rank correlation coefficient: 0.5425896367808437
# Average Pearson correlation: 0.52
# Average Spearman correlation: 0.54
